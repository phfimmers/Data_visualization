# %%
import pandas as pd

# %%
emre = pd.read_csv('csvfiles/EmreSaraJoachim.csv', index_col=0)
emre.head()
# Out:
#    Locality Type of property Subtype of property     Price Type of sale  \
# 0    1150.0            HOUSE               HOUSE  990000.0          NaN
# 1    4180.0            HOUSE               HOUSE  195000.0          NaN
# 2    7500.0      HOUSE_GROUP         HOUSE_GROUP       NaN          NaN
# 3    4180.0            HOUSE  MIXED_USE_BUILDING  295000.0          NaN
# 4    4570.0            HOUSE               HOUSE  549000.0          NaN
#
#    Number of rooms  Living surface area  Kitchen  Furnished  Open fire  \
# 0              6.0                485.0      1.0        0.0        0.0
# 1              3.0                242.0      1.0        0.0        0.0
# 2              NaN                  NaN      NaN        0.0        0.0
# 3              3.0                242.0      1.0        0.0        0.0
# 4              5.0                365.0      1.0        0.0        0.0
#
#    Terrace  Garden  Surface of the land  Number of facades  Swimming pool  \
# ...

# %%
emre.shape
# Out:
# (11523, 16)

# %%
emre.columns
# Out:
# Index(['Locality', 'Type of property', 'Subtype of property', 'Price',
#        'Type of sale', 'Number of rooms', 'Living surface area', 'Kitchen',
#        'Furnished', 'Open fire', 'Terrace', 'Garden', 'Surface of the land',
#        'Number of facades', 'Swimming pool', 'State of the building'],
#       dtype='object')

# %%
col_names = ['Locality', 'Type of property', 'Subtype of property', 'Price',
       'Type of sale', 'Number of rooms', 'Living surface area', 'Kitchen',
       'Furnished', 'Open fire', 'Terrace', 'Garden', 'Surface of the land',
       'Number of facades', 'Swimming pool', 'State of the building']

# %% [markdown]
# ### I change orhan's column's order

# %%
orhan = pd.read_csv('csvfiles/orhandavycristophe.csv', index_col=0)
orhan.head()
# Out:
#         type_property    type_subproperty   price  locality  \
# 8901695         HOUSE  MIXED_USE_BUILDING  295000      4180
# 8747010         HOUSE               VILLA  675000      8730
# 8775843         HOUSE     APARTMENT_BLOCK  250000      4020
# 8910441         HOUSE               HOUSE  545000      1200
# 8758672         HOUSE  MIXED_USE_BUILDING  500000      1190
#
#          netHabitableSurface  nr_bedrooms  kitchen_installed  nr_facades  \
# 8901695                  242            3               True           0
# 8747010                  349            4               True           0
# 8775843                  303            5               True           0
# 8910441                  235            4               True           0
# 8758672                  220            2               True           0
#
#          hasGarden  garden_m2  hasTerrace  terrace_m2  furnished_YN  \
# 8901695       True       1000        True          36         False
# ...

# %%
orhan2 = orhan[['locality', 'type_property', 'type_subproperty', 'price', 'type_of_sale', 'nr_bedrooms', 'netHabitableSurface', 'kitchen_installed', 'furnished_YN', 'fireplaceExist', 'terrace_m2', 'garden_m2', 'land', 'nr_facades', 'swimpool_YN', 'building']]
orhan2.head()
# Out:
#          locality type_property    type_subproperty   price type_of_sale  \
# 8901695      4180         HOUSE  MIXED_USE_BUILDING  295000   isNewPrice
# 8747010      8730         HOUSE               VILLA  675000   isNewPrice
# 8775843      4020         HOUSE     APARTMENT_BLOCK  250000   isNewPrice
# 8910441      1200         HOUSE               HOUSE  545000          NaN
# 8758672      1190         HOUSE  MIXED_USE_BUILDING  500000          NaN
#
#          nr_bedrooms  netHabitableSurface  kitchen_installed  furnished_YN  \
# 8901695            3                  242               True         False
# 8747010            4                  349               True         False
# 8775843            5                  303               True         False
# 8910441            4                  235               True          True
# 8758672            2                  220               True         False
#
# ...

# %%
orhan2.shape
# Out:
# (19965, 16)

# %%
orhan2.columns = col_names

# %%
orhan2.head()
# Out:
#          Locality Type of property Subtype of property   Price Type of sale  \
# 8901695      4180            HOUSE  MIXED_USE_BUILDING  295000   isNewPrice
# 8747010      8730            HOUSE               VILLA  675000   isNewPrice
# 8775843      4020            HOUSE     APARTMENT_BLOCK  250000   isNewPrice
# 8910441      1200            HOUSE               HOUSE  545000          NaN
# 8758672      1190            HOUSE  MIXED_USE_BUILDING  500000          NaN
#
#          Number of rooms  Living surface area  Kitchen  Furnished  Open fire  \
# 8901695                3                  242     True      False      False
# 8747010                4                  349     True      False      False
# 8775843                5                  303     True      False      False
# 8910441                4                  235     True       True      False
# 8758672                2                  220     True      False      False
#
# ...

# %% [markdown]
# ## First Concat

# %%
emre_orhan = pd.concat([emre, orhan2])
emre_orhan.head()
# Out:
#    Locality Type of property Subtype of property     Price Type of sale  \
# 0    1150.0            HOUSE               HOUSE  990000.0          NaN
# 1    4180.0            HOUSE               HOUSE  195000.0          NaN
# 2    7500.0      HOUSE_GROUP         HOUSE_GROUP       NaN          NaN
# 3    4180.0            HOUSE  MIXED_USE_BUILDING  295000.0          NaN
# 4    4570.0            HOUSE               HOUSE  549000.0          NaN
#
#    Number of rooms  Living surface area  Kitchen  Furnished  Open fire  \
# 0              6.0                485.0      1.0        0.0        0.0
# 1              3.0                242.0      1.0        0.0        0.0
# 2              NaN                  NaN      NaN        0.0        0.0
# 3              3.0                242.0      1.0        0.0        0.0
# 4              5.0                365.0      1.0        0.0        0.0
#
#    Terrace  Garden  Surface of the land  Number of facades  Swimming pool  \
# ...

# %%
emre_orhan.shape
# Out:
# (31488, 16)

# %% [markdown]
# ## Angel_Voelkers dataset

# %%
angel = pd.read_csv('csvfiles/Engel_Voelkers.csv', index_col=0)
angel.head()
# Out:
#                 Locality Type of Property                  Sub Type  \
# 0.0   Antwerpen-Centrum              Huis          Historische pand
# 1.0         Lasne/Ohain            Maison  Établissement historique
# 2.0      Antwerpen-Noord             Huis                     Villa
# 3.0      Antwerpen-Noord             Huis          Historische pand
# 4.0   Sint-Martens-Latem             Huis          Historische pand
#
#             Price Type of Sale No of Rooms Area(sqft) Equipped(Y/N)  \
# 0.0   12,500,000          Huis           8  20.343,79           NaN
# 1.0    6,500,000        Maison          16         18           NaN
# 2.0    5,850,000          Huis          10  12.163,22           NaN
# 3.0    4,950,000          Huis          30  26.909,78           NaN
# 4.0    4,800,000          Huis        None      11,12           NaN
#
#     Furnished(Y/N) Open Fire(Y/N) Terrace Area Garden Area  \
# 0.0            NaN            NaN          NaN         NaN
# ...

# %%
angel.shape
# Out:
# (4618, 17)

# %%
col_names2 = ['Locality', 'Type of property', 'Subtype of property', 'Price',
       'Type of sale', 'Number of rooms', 'Living surface area', 'Kitchen',
       'Furnished', 'Open fire', 'Terrace', 'Garden', 'Surface of the land',
       'Surface area of the Plot(sqft)',
       'Number of facades', 'Swimming pool', 'State of the building']

# %%
angel.columns = col_names2

# %% [markdown]
# ## Second Concat

# %%
emre_orhan_angel = pd.concat([emre_orhan, angel])
emre_orhan_angel.head()
# Out:
#     Locality Type of property Subtype of property   Price Type of sale  \
# 0.0     1150            HOUSE               HOUSE  990000          NaN
# 1.0     4180            HOUSE               HOUSE  195000          NaN
# 2.0     7500      HOUSE_GROUP         HOUSE_GROUP     NaN          NaN
# 3.0     4180            HOUSE  MIXED_USE_BUILDING  295000          NaN
# 4.0     4570            HOUSE               HOUSE  549000          NaN
#
#     Number of rooms Living surface area Kitchen Furnished Open fire Terrace  \
# 0.0               6                 485       1         0         0      16
# 1.0               3                 242       1         0         0      36
# 2.0             NaN                 NaN     NaN         0         0       0
# 3.0               3                 242       1         0         0      36
# 4.0               5                 365       1         0         0      15
#
#     Garden Surface of the land Number of facades Swimming pool  \
# ...

# %%
emre_orhan_angel.shape
# Out:
# (36106, 17)

# %% [markdown]
# ## Selma Datasets

# %%
selma = pd.read_csv('csvfiles/SelmaAnkitaAdam.csv')
selma.head()
# Out:
#   Locality type of property    price    area building state rooms  facades  \
# 0     1861            House  359000€  120 m²  Not specified     3      3.0
# 1     1860            House  359000€  120 m²  Not specified     3      3.0
# 2     3270            House  349000€  215 m²           Good     3      4.0
# 3     2500            House  309000€  130 m²           Good     3      2.0
# 4     1950            House  648000€  130 m²           Good     3      3.0
#
#     kitchen type  garden  fireplace  swimming pool
# 0  Not specified     1.0        0.0            0.0
# 1  Not specified     1.0        0.0            0.0
# 2      Installed     1.0        0.0            0.0
# 3  Semi equipped     1.0        0.0            0.0
# 4  Not specified     1.0        0.0            0.0

# %%
selma.shape
# Out:
# (8325, 11)

# %%
selma2 = selma[['Locality', 'type of property', 'price', 'rooms', 'area',  'kitchen type', 'fireplace', 'garden', 'facades', 'swimming pool', 'building state']]

# %%
col_names3 = ['Locality', 'Type of property', 'Price', 'Living surface area', 'Number of rooms', 'Kitchen',
       'Open fire', 'Garden',
       'Number of facades', 'Swimming pool', 'State of the building']

# %%
selma2.columns = col_names3

# %% [markdown]
# ## Third Concat

# %%
emre_orhan_angel_selma = pd.concat([emre_orhan_angel, selma2])
emre_orhan_angel_selma.head()
# Out:
#     Locality Type of property Subtype of property   Price Type of sale  \
# 0.0     1150            HOUSE               HOUSE  990000          NaN
# 1.0     4180            HOUSE               HOUSE  195000          NaN
# 2.0     7500      HOUSE_GROUP         HOUSE_GROUP     NaN          NaN
# 3.0     4180            HOUSE  MIXED_USE_BUILDING  295000          NaN
# 4.0     4570            HOUSE               HOUSE  549000          NaN
#
#     Number of rooms Living surface area Kitchen Furnished Open fire Terrace  \
# 0.0               6                 485       1         0         0      16
# 1.0               3                 242       1         0         0      36
# 2.0             NaN                 NaN     NaN         0         0       0
# 3.0               3                 242       1         0         0      36
# 4.0               5                 365       1         0         0      15
#
#     Garden Surface of the land Number of facades Swimming pool  \
# ...

# %%
emre_orhan_angel_selma.shape
# Out:
# (44431, 17)

# %% [markdown]
# ## Immoweb dataset

# %%
immoweb = pd.read_csv('csvfiles/immoweb.csv', index_col=0)
immoweb.head()
# Out:
#               Locality Type of Property Subtype of property     Price  \
# Immoweb code
# 8954833.0         1861            House               House  €359,000
# 8954832.0         1860            House               House  €359,000
# 8954827.0         3270            House               House  €349,000
# 8954826.0         2500            House               House  €309,000
# 8954824.0         1950            House               House  €648,000
#
#              Type of sale No_of_rooms  area   Kitchen type  Furnished   \
# Immoweb code
# 8954833.0        for sale           3   120              0           0
# 8954832.0        for sale           3   120              0           0
# 8954827.0        for sale           3   215      Installed           0
# 8954826.0        for sale           3   130  Semi equipped           0
# 8954824.0        for sale           3   130              0           0
#
#               Fireplace  Terrace Garden  Facades  Swimming pool  \
# Immoweb code
# ...

# %%
col_names4 = ['Locality', 'Type of property', 'Subtype of property', 'Price',
       'Type of sale', 'Number of rooms', 'Living surface area', 'Kitchen',
       'Furnished', 'Open fire', 'Terrace', 'Garden', 
       'Number of facades', 'Swimming pool', 'State of the building']

# %%
immoweb.columns = col_names4

# %% [markdown]
# ## fourth concat

# %%
emre_orhan_angel_selma_immoweb = pd.concat([emre_orhan_angel_selma, immoweb])
emre_orhan_angel_selma_immoweb.head()
# Out:
#     Locality Type of property Subtype of property   Price Type of sale  \
# 0.0     1150            HOUSE               HOUSE  990000          NaN
# 1.0     4180            HOUSE               HOUSE  195000          NaN
# 2.0     7500      HOUSE_GROUP         HOUSE_GROUP     NaN          NaN
# 3.0     4180            HOUSE  MIXED_USE_BUILDING  295000          NaN
# 4.0     4570            HOUSE               HOUSE  549000          NaN
#
#     Number of rooms Living surface area Kitchen Furnished Open fire Terrace  \
# 0.0               6                 485       1         0         0      16
# 1.0               3                 242       1         0         0      36
# 2.0             NaN                 NaN     NaN         0         0       0
# 3.0               3                 242       1         0         0      36
# 4.0               5                 365       1         0         0      15
#
#     Garden Surface of the land Number of facades Swimming pool  \
# ...

# %%
emre_orhan_angel_selma_immoweb.shape
# Out:
# (56035, 17)

# %% [markdown]
# ## mikael datasets
